# %% [markdown]
# RACE AND DIVERSITY ANALYSIS BY KAHDIJAH LEMAINE

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
demographic_data = pd.read_csv("C:/Users/klema/tkh_career_analysis/HRDataset_v14.csv")

# %%
demographic_data.shape
# Out:
# (311, 36)

# %%
demographic_data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
demographic_data.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
demographic_data.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
#Here I am looking to see if the company does employee non-US Citizens who are eligible to work in the US as well as those who are not 
#eligible to work in the US.
citizen_info = demographic_data.value_counts("CitizenDesc")
citizen_info
# Out:
# CitizenDesc
# US Citizen             295
# Eligible NonCitizen     12
# Non-Citizen              4
# Name: count, dtype: int64

# %%
#Here in this code, I am calculating the percentage of each group.
citizen_percentages = (citizen_info / citizen_info.sum()) * 100
citizen_percentages
# Out:
# CitizenDesc
# US Citizen             94.855305
# Eligible NonCitizen     3.858521
# Non-Citizen             1.286174
# Name: count, dtype: float64

# %%
citizen_percentages.plot(kind="pie", autopct="%1.1f%%", colors=["blue", "red", "green"], figsize=(6,6))
plt.title("Citizenship Breakdown")
plt.ylabel("")
plt.show()

# %%
#This code allows us to see the average salary for each group.
citizen_avg_salary = demographic_data.groupby("CitizenDesc")["Salary"].mean().sort_values(ascending=False)
print("Average Salary by Race")
citizen_avg_salary
# Out:
# Average Salary by Race
# CitizenDesc
# Eligible NonCitizen    72768.333333
# Non-Citizen            72366.000000
# US Citizen             68822.877966
# Name: Salary, dtype: float64

# %%
citizen_avg_salary.plot(kind="barh", color="skyblue", figsize=(8,5))

plt.title("Average Salary by Citizenship Status")
plt.xlabel("Average Salary ($)")
plt.ylabel("Citizenship Status")
plt.grid(axis="x", alpha=0.7)

plt.show()

# %%
#This code will allow us to see the average performance review score for US Citizens compared to Non-US Citizens.
citizen_avg_score = demographic_data.groupby("CitizenDesc")["PerfScoreID"].mean().sort_values(ascending=False)
print("Average Performace Score Based on Citizenship")
citizen_avg_score
# Out:
# Average Performace Score Based on Citizenship
# CitizenDesc
# Non-Citizen            3.000000
# US Citizen             2.979661
# Eligible NonCitizen    2.916667
# Name: PerfScoreID, dtype: float64

# %%
citizen_avg_score.plot(kind="barh", color="skyblue", figsize=(8,5), edgecolor="black")

plt.title("Average Performance Score Based on U.S. Citizenship", fontsize=14, fontweight="bold")
plt.xlabel("Performance Score", fontsize=12)
plt.ylabel("U.S. Citizenship Status", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.7)

plt.show()

# %%
#Here we will review how many employees identify as Hispanic/Lation or not.
hispanic_latino = demographic_data.value_counts("HispanicLatino")
hispanic_latino
# Out:
# HispanicLatino
# No     282
# Yes     27
# no       1
# yes      1
# Name: count, dtype: int64

# %% [markdown]
# In the code above, we see that since some responses in the data set begin with a lowercase 'y' and/or 'n', they are being interpreted as separate unique responses. We have to correct this in order to get an accurate percentage.

# %%
demographic_data["HispanicLatino"] = demographic_data["HispanicLatino"].str.upper()

# %%
hispanic_latino = demographic_data.value_counts("HispanicLatino")
hispanic_latino
# Out:
# HispanicLatino
# NO     283
# YES     28
# Name: count, dtype: int64

# %% [markdown]
# Now we see that the count has been correctly adjusted by coverting all responses to all uppercase string characters.

# %%
#Here we get the percentage of that count.
hispanic_counts = demographic_data["HispanicLatino"].value_counts()
hispanic_percentages = (hispanic_counts / hispanic_counts.sum()) * 100

for response, percentage in hispanic_percentages.items():
    print(f"Percentage of {response}: {percentage:.2f}%")
# Out:
# Percentage of NO: 91.00%
# Percentage of YES: 9.00%

# %%
#We can see this percentage visualized in the bar graph below.
plt.bar(hispanic_percentages.index, hispanic_percentages.values, color=['skyblue', 'salmon'])

plt.xlabel("Response")
plt.ylabel("Percentage")
plt.title("Hispanic/Latino Representation")

plt.show()

# %%
#In this code block, we will find the average salary for those who identify as Hispanic/Latino compare to those who do not.
avg_latx_sal = demographic_data.groupby("HispanicLatino")["Salary"].mean()

print(avg_latx_sal)
# Out:
# HispanicLatino
# NO     68502.469965
# YES    74258.357143
# Name: Salary, dtype: float64

# %%
avg_latx_sal.plot(kind="bar", color=["skyblue", "salmon"])

plt.xlabel("Hispanic/Latino Identification")
plt.ylabel("Average Salary")
plt.title("Average Salary by Hispanic/Latino Identification")

plt.show()

# %%
#Here we get the average performance review score for each group.
avg_latx_score = demographic_data.groupby("HispanicLatino")["PerfScoreID"].mean()

print(avg_latx_score)
# Out:
# HispanicLatino
# NO     2.975265
# YES    3.000000
# Name: PerfScoreID, dtype: float64

# %%
avg_latx_score.plot(kind="barh", color="mediumseagreen", figsize=(8,5), edgecolor="black")

plt.title("Average Performance Score by Hispanic/Lation Identification", fontsize=14, fontweight="bold")
plt.xlabel("Performance Score", fontsize=12)
plt.ylabel("Identifies as Hispanic/Latino", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.7)

plt.show()

# %%
#Here we will count the amount of employees by race.
race_df = demographic_data.value_counts("RaceDesc")
race_df
# Out:
# RaceDesc
# White                               187
# Black or African American            80
# Asian                                29
# Two or more races                    11
# American Indian or Alaska Native      3
# Hispanic                              1
# Name: count, dtype: int64

# %%
#In this code block we will determine the percentage of each racial group within the company.
race_counts = demographic_data["RaceDesc"].value_counts()
race_percentages = (race_counts / race_counts.sum()) * 100

for race, percentage in race_percentages.items():
    print(f"Percentage of {race}: {percentage:.2f}%")
# Out:
# Percentage of White: 60.13%
# Percentage of Black or African American: 25.72%
# Percentage of Asian: 9.32%
# Percentage of Two or more races: 3.54%
# Percentage of American Indian or Alaska Native: 0.96%
# Percentage of Hispanic: 0.32%

# %%
#Here we can see this visualized in a pie chart.
race_percentages.plot(kind="pie", autopct="%1.1f%%", figsize=(6,6), colormap="Pastel1")
plt.title("Race Distribution in the Company")
plt.ylabel("") 
plt.show()

# %%
white_median_salary = demographic_data[demographic_data["RaceDesc"] == "White"]["Salary"].median()
minority_median_salary = demographic_data[demographic_data["RaceDesc"] != "White"]["Salary"].median()

print(white_median_salary)
print(minority_median_salary)
# Out:
# 62068.0
# 63729.0

# %%
equity_ratio = minority_median_salary / white_median_salary
print(f"Equity Ratio: {equity_ratio:.2f}")
# Out:
# Equity Ratio: 1.03

# %%
# Here we will calculate the average salary according to each race.
avg_sal_per_race = demographic_data.groupby("RaceDesc")["Salary"].mean().sort_values(ascending=False)
print("Average Salary by Race")
avg_sal_per_race
# Out:
# Average Salary by Race
# RaceDesc
# Hispanic                            83667.000000
# Black or African American           74431.025000
# Asian                               68521.206897
# White                               67287.545455
# American Indian or Alaska Native    65806.000000
# Two or more races                   59998.181818
# Name: Salary, dtype: float64

# %%
avg_sal_per_race.plot(kind="barh", color="steelblue", figsize=(8,5), edgecolor="black")

plt.title("Average Salary by Race", fontsize=14, fontweight="bold")
plt.xlabel("Average Salary ($)", fontsize=12)
plt.ylabel("Race", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.7)

plt.show()

# %%
#Here we will calculate the averarge performance score according to race.

avg_perf_score = demographic_data.groupby("RaceDesc")["PerfScoreID"].mean().sort_values(ascending=False)
print("Average Performance Score by Race")
avg_perf_score
# Out:
# Average Performance Score by Race
# RaceDesc
# American Indian or Alaska Native    3.333333
# Black or African American           3.012500
# Hispanic                            3.000000
# White                               2.983957
# Asian                               2.896552
# Two or more races                   2.727273
# Name: PerfScoreID, dtype: float64

# %%
avg_perf_score.plot(kind="barh", color="mediumseagreen", figsize=(8,5), edgecolor="black")

plt.title("Average Performance Score by Race", fontsize=14, fontweight="bold")
plt.xlabel("Performance Score", fontsize=12)
plt.ylabel("Race", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.7)

plt.show()

# %%
# Here we will get the count of termination reason across each specific racial group.
termination_percentages = (
    demographic_data.groupby("RaceDesc")["TermReason"]
    .value_counts(normalize=True) * 100
)

print(termination_percentages)
# Out:
# RaceDesc                          TermReason
# American Indian or Alaska Native  N/A-StillEmployed                   100.000000
# Asian                             N/A-StillEmployed                    68.965517
#                                   Another position                     10.344828
#                                   unhappy                              10.344828
#                                   more money                            3.448276
#                                   retiring                              3.448276
#                                   return to school                      3.448276
# Black or African American         N/A-StillEmployed                    63.750000
#                                   Another position                      8.750000
#                                   career change                         5.000000
#                                   attendance                            3.750000
# ...

# %%
# Here I have excluded the rows where "TermReason" is "N/A-StillEmployed". This will allow us to exclude those who are still employed with the company.
filtered_data = demographic_data[demographic_data["TermReason"] != "N/A-StillEmployed"]
filtered_data
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# 10       Baczenski, Rachael    10252          1                1         0
# 11            Barbara, Thomas  10242          1                1         1
# ..                        ...    ...        ...              ...       ...
# 301             Wilber, Barry  10048          1                1         1
# 302             Wilkes, Annie  10204          0                2         0
# 303     Williams, Jacquelyn    10264          0                0         0
# 304        Winthrop, Jordan    10033          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
#
# ...

# %%
#Now we can see the percentage of each termination reason for each race.
termination_percentages = (
    filtered_data.groupby("RaceDesc")["TermReason"]
    .value_counts(normalize=True) * 100
)

print(termination_percentages)
# Out:
# RaceDesc                   TermReason
# Asian                      Another position                    33.333333
#                            unhappy                             33.333333
#                            more money                          11.111111
#                            retiring                            11.111111
#                            return to school                    11.111111
# Black or African American  Another position                    24.137931
#                            career change                       13.793103
#                            attendance                          10.344828
#                            hours                               10.344828
#                            no-call, no-show                     6.896552
#                            return to school                     6.896552
#                            unhappy                              6.896552
# ...

# %%
termination_df = termination_percentages.unstack()

termination_df.plot(kind="bar", stacked=True, figsize=(10,6), colormap="viridis")

plt.xlabel("Race")
plt.ylabel("Percentage of Terminations")
plt.title("Termination Reasons Across Racial Groups")
plt.legend(title="Termination Reason", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.show()

# %% [markdown]
# Question 1: Is there evidence to suggest implicit or explicit bias in salary allocation based on citizenship status?
#
# After analyzing the data of employees that are US citizens compared to those who are non US citizens, I have determined that employees are not treated differently according to their imingration status.
#
# Although Non-US citizens makeup a little more than 5% of the company, they are amongst the most highest paid. Earning about $5,000 on average annually more than US citiziens.
#
# The performace score also reflects a pretty fair picture as to how one group is assessed compared to the other. The difference in performace scores between the groups is less than 1 point.

# %% [markdown]
# Question 2: Does identifying as Hispanic or Latino impact salary or job classification within the company?
#
# To answer this question, I calculated the average salary of thos who identified as Hispanic or Latino compared to those who did not. The findings indicate no evidence of differential treatment based on this identification.
#
# While there is an approximate $5,000 annual salary difference between the two groups, this variation cannot be directly attributed to whether an employee identifies as Hispanic or Latino.
#
# Similarly, the average performance review scores show only a negligible difference, reinforcing that there is no indication of bias in evaluations based on this factor.

# %% [markdown]
# Question 3: Are performance assessments distributed fairly across racial demographics?
#
# To answer this question, I analyzed performance review scores across racial groups. Based on the data, there is no observable relationship between race and performance evaluations. Across all racial groups, average review scores remain consistently between 2.7 and 3.3, indicating that race does not appear to be a determining factor in assessment outcomes.

# %% [markdown]
# Question 4: Are there any statistically significant differences in termination rates that could suggest bias or inequitable workplace conditions?
#
# I examined the various termination reasons across racial groups. The most common reason for departure in the dataset is voluntary resignation due to securing another position, consistently ranking as the top reason across all racial demographics, with percentages ranging from 24% to 33%. While employees of different races cited various reasons for leaving the company, the data does not indicate any termination patterns associated with racial bias orinequitable workplace conditions.

# %% [markdown]
# Question 5: Is there a statistically significant difference in average salary across racial groups?
#
# Although White employees make up the majority of the workforce, the data does not indicate that they receive preferential compensation compared to other racial groups. In fact, when analyzing average salaries across race, African American employees rank among the highest paid, earning an average annual salary of nearly $75,000. While the data suggests that Hispanic employees have the highest average salary, this finding is somewhat skewed due to the presence of White employees who also identify as Hispanic.

# %% [markdown]
# Question 6: What hiring strategies could improve diversity among underrepresented racial groups?
#
# Upon examining workforce demographics, I found that White employees make up the majority at just over 60% of total staff, while African American employees represent approximately 26% and Asian employees account for less than 10%. To improve diversity among underrepresented racial groups, the company should implement more inclusive hiring strategies, such as expanding recruitment efforts in diverse talent pools, strengthening partnerships with minority-focused professional organizations, and ensuring equitable access to advancement opportunities. These initiatives can help create a more representative workforce that better reflects a commitment to diversity and inclusion.
