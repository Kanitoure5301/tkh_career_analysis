# %% [markdown]
# RACE AND DIVERSITY ANALYSIS BY KAHDIJAH LEMAINE

# %% [markdown]
# This study aims to provide a comprehensive diversity profile of the company, examining the role of race and representation across key aspects of employment. By analyzing factors such as salary, position, performance reviews, length of employment, and termination trends, this research seeks to identify potential relationships between race and workplace outcomes.
#
# Beyond understanding demographic composition, this analysis offers insight into whether implicit or explicit discrimination may exist, helping prospective employees make informed career decisions. The findings will contribute to a data-driven perspective on workplace equity, ensuring transparency in employment practices.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
demographic_data = pd.read_csv("C:/Users/klema/tkh_career_analysis/HRDataset_v14.csv")

# %%
demographic_data.shape
# Out:
# (311, 36)

# %%
demographic_data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
# 4  Webster Butler       39.0     Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
# 3              4.84               5                    0
# 4              5.00               4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# 1                  2/24/2016              0       17
# 2                  5/15/2012              0        3
# 3                   1/3/2019              0       15
# 4                   2/1/2016              0        2
#
# [5 rows x 36 columns]

# %%
demographic_data.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# min      1.000000     1.000000                0.000000   45046.000000
# 25%      5.000000     3.000000                0.000000   55501.500000
# 50%      5.000000     3.000000                0.000000   62810.000000
# 75%      5.000000     3.000000                0.000000   72036.000000
# max      6.000000     4.000000                1.000000  250000.000000
#
#             Termd  PositionID           Zip   ManagerID  EngagementSurvey  \
# count  311.000000  311.000000    311.000000  303.000000        311.000000
# mean     0.334405   16.845659   6555.482315   14.570957          4.110000
# std      0.472542    6.223419  16908.396884    8.078306          0.789938
# min      0.000000    1.000000   1013.000000    1.000000          1.120000
# 25%      0.000000   18.000000   1901.500000   10.000000          3.690000
# 50%      0.000000   19.000000   2132.000000   15.000000          4.280000
# 75%      1.000000   20.000000   2355.000000   19.000000          4.700000
# max      1.000000   30.000000  98052.000000   39.000000          5.000000
#
#        EmpSatisfaction  SpecialProjectsCount  DaysLateLast30    Absences
# count       311.000000            311.000000      311.000000  311.000000
# mean          3.890675              1.218650        0.414791   10.237942
# std           0.909241              2.349421        1.294519    5.852596
# min           1.000000              0.000000        0.000000    1.000000
# 25%           3.000000              0.000000        0.000000    5.000000
# 50%           4.000000              0.000000        0.000000   10.000000
# 75%           5.000000              0.000000        0.000000   15.000000
# max           5.000000              8.000000        6.000000   20.000000

# %%
demographic_data.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ManagerID                       8
# RecruitmentSource               0
# PerformanceScore                0
# EngagementSurvey                0
# EmpSatisfaction                 0
# SpecialProjectsCount            0
# LastPerformanceReview_Date      0
# DaysLateLast30                  0
# Absences                        0
# dtype: int64

# %%
#Here I am looking to see if the company does employee non-US Citizens who are eligible to work in the US as well as those who are not 
#eligible to work in the US.
citizen_info = demographic_data.value_counts("CitizenDesc")
citizen_info
# Out:
# CitizenDesc
# US Citizen             295
# Eligible NonCitizen     12
# Non-Citizen              4
# Name: count, dtype: int64

# %%
citizen_percentages = (citizen_info / citizen_info.sum()) * 100
citizen_percentages
# Out:
# CitizenDesc
# US Citizen             94.855305
# Eligible NonCitizen     3.858521
# Non-Citizen             1.286174
# Name: count, dtype: float64

# %%
citizen_percentages.plot(kind="pie", autopct="%1.1f%%", colors=["blue", "red", "green"], figsize=(6,6))
plt.title("Citizenship Breakdown")
plt.ylabel("")  # Hide y-axis label
plt.show()

# %%
citizen_avg_salary = demographic_data.groupby("CitizenDesc")["Salary"].mean().sort_values(ascending=False)
print("Average Salary by Race")
citizen_avg_salary
# Out:
# Average Salary by Race
# CitizenDesc
# Eligible NonCitizen    72768.333333
# Non-Citizen            72366.000000
# US Citizen             68822.877966
# Name: Salary, dtype: float64

# %%
citizen_avg_salary.plot(kind="barh", color="skyblue", figsize=(8,5))

plt.title("Average Salary by Citizenship Status")
plt.xlabel("Average Salary ($)")
plt.ylabel("Citizenship Status")
plt.grid(axis="x", alpha=0.7)

plt.show()

# %% [markdown]
# As a US compnay, it is expected that the majority of employees will be US Citizens. However, the data shows that the company is
# willing to employee a little over 5% non US citizens; both who may or may not be eligible to work in the United States at the moment.
# This can be an indication that this company is willing to sponsor work visas or a path to obtaining work visas to those employees willing to work hard.
#
# When we examine the bar graph to look at the salary comparison between the 3 groups, we can see non US citizens actually are paid more on average than US citizens. Which clearly indicates that there is no pay discrimintation occuring or employees are not being exploited due to their imigration status.

# %%
#Here we will count the amount of employees by race.
race_df = demographic_data.value_counts("RaceDesc")
race_df
# Out:
# RaceDesc
# White                               187
# Black or African American            80
# Asian                                29
# Two or more races                    11
# American Indian or Alaska Native      3
# Hispanic                              1
# Name: count, dtype: int64

# %%
race_counts = demographic_data["RaceDesc"].value_counts()
race_percentages = (race_counts / race_counts.sum()) * 100

# Loop through each race category and format output
for race, percentage in race_percentages.items():
    print(f"Percentage of {race}: {percentage:.2f}%")
# Out:
# Percentage of White: 60.13%
# Percentage of Black or African American: 25.72%
# Percentage of Asian: 9.32%
# Percentage of Two or more races: 3.54%
# Percentage of American Indian or Alaska Native: 0.96%
# Percentage of Hispanic: 0.32%

# %%
race_percentages.plot(kind="pie", autopct="%1.1f%%", figsize=(6,6), colormap="Pastel1")
plt.title("Race Distribution in the Company")
plt.ylabel("")  # Hide y-label for clarity
plt.show()

# %%
# Here we will calculate the average salary according to each race.
avg_sal_per_race = demographic_data.groupby("RaceDesc")["Salary"].mean().sort_values(ascending=False)
print("Average Salary by Race")
avg_sal_per_race
# Out:
# Average Salary by Race
# RaceDesc
# Hispanic                            83667.000000
# Black or African American           74431.025000
# Asian                               68521.206897
# White                               67287.545455
# American Indian or Alaska Native    65806.000000
# Two or more races                   59998.181818
# Name: Salary, dtype: float64

# %%
avg_sal_per_race.plot(kind="barh", color="steelblue", figsize=(8,5), edgecolor="black")

plt.title("Average Salary by Race", fontsize=14, fontweight="bold")
plt.xlabel("Average Salary ($)", fontsize=12)
plt.ylabel("Race", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.7)

plt.show()

# %%
#Here we will calculate the averarge performance score according to race.

avg_perf_score = demographic_data.groupby("RaceDesc")["PerfScoreID"].mean().sort_values(ascending=False)
print("Average Performance Score by Race")
avg_perf_score
# Out:
# Average Performance Score by Race
# RaceDesc
# American Indian or Alaska Native    3.333333
# Black or African American           3.012500
# Hispanic                            3.000000
# White                               2.983957
# Asian                               2.896552
# Two or more races                   2.727273
# Name: PerfScoreID, dtype: float64

# %%
#Now we will visualize this data into a Bar Graph.
avg_perf_score.plot.barh()
plt.title("Average Performance Score per Race")
plt.xlabel("PerfScoreID")
plt.ylabel("Race")
# Out:
# Text(0, 0.5, 'Race')

# %%
avg_perf_score.plot(kind="barh", color="mediumseagreen", figsize=(8,5), edgecolor="black")

# Formatting the chart
plt.title("Average Performance Score by Race", fontsize=14, fontweight="bold")
plt.xlabel("Performance Score", fontsize=12)
plt.ylabel("Race", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.7)

plt.show()
